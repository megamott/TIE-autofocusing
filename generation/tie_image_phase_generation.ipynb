# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage.restoration import unwrap_phase
from mpl_toolkits.axes_grid1 import make_axes_locatable
from miscellaneous.loader import load_file

# %%
file = 'image/TIE_Single.tif'
phase = load_file(file)
plt.imshow(phase, cmap='gray')
plt.colorbar()
plt.show()

# %%
i_amplitude = 0.5
intensity = i_amplitude * np.ones(phase.shape)
complex_field = np.sqrt(intensity) * np.exp(1j * phase)

# %%
fig = plt.figure(dpi=100, figsize=[12,8])
ax1, ax2 = fig.add_subplot(1, 2, 1), fig.add_subplot(1, 2, 2)

intensity = np.abs(complex_field) ** 2

img1 = ax1.imshow(intensity, cmap='gray')
divider1 = make_axes_locatable(ax1)
cax1 = divider1.append_axes("right", size="5%", pad=0.05)
cbar1 = plt.colorbar(img1, cax=cax1)

ax1.grid(True)
ax1.title.set_text('intensity')
ax1.set_xlabel('x')
ax1.set_ylabel('y')

phase = unwrap_phase(np.angle(complex_field))

img2 = ax2.imshow(phase, cmap='gray')
divider2 = make_axes_locatable(ax2)
cax2 = divider2.append_axes("right", size="5%", pad=0.05)
cbar2 = plt.colorbar(img2, cax=cax2)

ax2.grid(True)
ax2.title.set_text('phase')
ax2.set_xlabel('x')

plt.show()

# %%
np.save('fields/tie_phase/TIE_Single.npy', complex_field)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\IGRITS~1\AppData\Local\Temp\6/ipykernel_14580/2169181588.py in <module>
# ----> 1 np.save('fields/tie_phase/TIE_Single.npy', complex_field)
#
# <__array_function__ internals> in save(*args, **kwargs)
#
# c:\users\igritsenko\.virtualenvs\tie-autofocusing\lib\site-packages\numpy\lib\npyio.py in save(file, arr, allow_pickle, fix_imports)
#     523         if not file.endswith('.npy'):
#     524             file = file + '.npy'
# --> 525         file_ctx = open(file, "wb")
#     526
#     527     with file_ctx as fid:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'fields/tie_phase/TIE_Single.npy'
